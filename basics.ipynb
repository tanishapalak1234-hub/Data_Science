# %%
##case sensitivity of python
Name="krish"
name="Naik"
print(name)
print(Name)
# Out:
# Naik
# krish

# %%
##indentation in python.
age=32
if (age<30):
    print(age)
print(age)
# Out:
# 32

# %%
 ##This is a single line comment.
print("hello world")
# Out:
# hello world

# %%
##line continuation in python
total=1+2+3+4+5+6+\
7+8
print(total)
# Out:
# 36

# %%
##mutliple lines in single statement.
x=5; y=10; z=x+y
print(z)
# Out:
# 15

# %%
age=32
name='palak'

# %%
type(age)
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
##type inference
variable=10
print(type(variable))
variable='hello palak'
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
##declaring and assigning values to variables.
age=32
name='palak'
bf='ritesh'
his_love= 'me and only me'
his_height=5.11

print(age)
print(name)
print(bf)
print(his_love)
print(his_height)
# Out:
# 32
# palak
# ritesh
# me and only me
# 5.11

# %%
##type checking and conversion.
print(type(age))
type(age)
##type conversion
age_str=str(age)
print(type(age))
print(type(age_str))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
age='34'
print(age)
age_integer=int(age)
print(type(age_integer))
# Out:
# 34
# <class 'int'>

# %%
##float to int conversion
hii=8.4
print(type(hii))
hii_=float(int(hii))
print(hii)
print(hii_)
print(type(hii_))
# Out:
# <class 'float'>
# 8.4
# 8.0
# <class 'float'>

# %%
##DYNAMIC BINDING
##python allows to change the values of variables as and when the program changes.
var=10
print(var, type(var))
var='hii'
print(var, type(var))
var=7.89
print(var,type(var))
# Out:
# 10 <class 'int'>
# hii <class 'str'>
# 7.89 <class 'float'>

# %%
age=input("enter the age ")
print(age)
print(type(age))
# Out:
# 34
# <class 'str'>

# %%
age=int(input("enter the age "))
print(age)
print(type(age))

# %%
##data types in python.
##integer type
age=35
life=60
print(type(age))
# Out:
# <class 'int'>

# %%
##floating data type
height=7.89
print(type(height))
# Out:
# <class 'float'>

# %%
##string data type
name="ritesh kumar singh"
print(name)
print(type(name))
# Out:
# ritesh kumar singh
# <class 'str'>

# %%
##boolean data type
True
type(True)
is_true=True
type(is_true)

a=10
b=10
a==b
type(a==b)
# Out:
# bool

# %%
##common errors

hey='hello'+ 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 ##common errors
# ----> 3 hey='hello'+ 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
hey='hello'+str(5)
print(hey)
# Out:
# hello5
