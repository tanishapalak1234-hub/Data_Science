# %%
##arithmatic operations
a=100
b=10
add=a+b
sub=a-b
product=a*b
division=a/b
floor_division=a//b
modulus=a%b
exponent=a**b
print(add)
print(sub)
print(product)
print(division)
print(floor_division)
print(modulus)
print(exponent)
# Out:
# 110
# 90
# 1000
# 10.0
# 10
# 0
# 100000000000000000000

# %%
##comparison operators
a=10
b=10
print(a==b) ##compares the value of a and b
hey='KRISH'
HEY='krish'
print(hey==HEY) ## == is case sensitive
a!=b ##!= is not equals to its returns true only when the condition is false.
c=100
d=30
print(c>d)
print(c<d)
print(a>=b)
print(a<20)
# Out:
# True
# False
# True
# False
# True

# %%
## AND OR NOT
##and returns true only when both the conditions are true
##or returns true if any one of the case is true
##not is kind of comparison operator only it returns true only when the case given is not true.

a=True
b=True
c=False
d=False
print(a and b)
print(a and c)
print(a or b)
print(a or c)
print(c or d)
a=True
b=False
print(not b)
print(not a)
# Out:
# True
# False
# True
# True
# False
# True
# False
