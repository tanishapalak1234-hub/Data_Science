# %%
a=float(input("enter the number a"))
b=float(input("enter the number b"))
add=a+b
sub=a-b
product=a*b
division=a/b
floor_division=a//b
modulus=a%b
exponent=a**b
print(add)
print(sub)
print(product)
print(division)
print(floor_division)
print(modulus)
print(exponent)
# Out:
# 110.0
# 90.0
# 1000.0
# 10.0
# 10.0
# 0.0
# 1e+20
